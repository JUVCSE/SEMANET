# %%
#test train directory of dataset
train_dir = "/kaggle/input/newmiobdwithoutmulti/MIO-BD/train"
val_dir = "/kaggle/input/newmiobdwithoutmulti/MIO-BD/train"
test_dir = "/kaggle/input/newmiobdwithoutmulti/MIO-BD/test"

# %%
#import libraries
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Flatten, Dropout, InputLayer, BatchNormalization, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, Callback
from keras import regularizers
from keras import backend as K

import gc
import copy
# Out:
# 2024-08-30 16:41:28.568298: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-30 16:41:28.568419: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-30 16:41:28.677168: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
#image height width batch size declaration
img_height, img_width = 220, 220
batch_size = 32
num_classes = 19
num_snapshots = 3
num_epochs_per_snapshot = 12
final_epoch = 10

# %%
#training,testing and validation data generator 
train_datagen = ImageDataGenerator(rescale=1./255,rotation_range=20,
                                   width_shift_range=0.2,horizontal_flip=True,height_shift_range=0.2) 


val_datagen = ImageDataGenerator( rescale=1.0 / 255 )

test_datagen = ImageDataGenerator( rescale=1.0 / 255 )

train_generator = train_datagen.flow_from_directory( train_dir,
                                                    target_size=(img_height, img_width),
                                                    batch_size=batch_size, class_mode='categorical',
                                                    shuffle=True)

val_generator = test_datagen.flow_from_directory( val_dir,                                              
                                                  target_size=(img_height, img_width),
                                                  batch_size=batch_size, class_mode='categorical',
                                                  shuffle=False )

test_generator = test_datagen.flow_from_directory( test_dir,
                                                  target_size=(img_height, img_width),
                                                  batch_size=batch_size, class_mode='categorical',

                                                  shuffle=False )
# Out:
# Found 13377 images belonging to 19 classes.
# Found 13377 images belonging to 19 classes.
# Found 3288 images belonging to 19 classes.

# %%
#import tensorflow
import tensorflow as tf
from tensorflow.keras import layers, Model

from tensorflow.keras.layers import *

# %%
#define number of heads,dropout rate and reduction ratio
num_heads = 5
reduction_ratio = 8
dropout_rate = 0.02
l2_reg = 0.01

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.layers import GlobalAveragePooling2D, Reshape, Conv2D, Multiply, SeparableConv2D, LayerNormalization, Dropout, BatchNormalization

def multihead_attention(input_tensor, num_heads=5):
  # Split input into multiple heads
    input_shape = input_tensor.shape
    depth = input_shape[-1]
    # Adjust depth to ensure it is evenly divisible by num_heads
    new_depth = depth + (num_heads - (depth % num_heads))

    # Modify input tensor depth if necessary
    if new_depth != depth:
        input_tensor = tf.keras.layers.Conv2D(new_depth, kernel_size=(1, 1))(input_tensor)

    # Calculate depth per head
    depth_per_head = new_depth // num_heads

    # Channel attention
    channel_avg = layers.GlobalAveragePooling2D()(input_tensor)
    channel_max = layers.Lambda(lambda x: tf.reduce_max(x, axis=[1, 2]))(input_tensor)
    channel_concat = layers.Concatenate(axis=1)([channel_avg, channel_max])

    channel_dense1 = layers.Dense(units=depth // num_heads, activation='sigmoid')(channel_concat)
    channel_attention = layers.Reshape((1, 1, depth // num_heads))(channel_dense1)

    channel_attention = layers.UpSampling2D(size=(input_tensor.shape[1], input_tensor.shape[2]))(channel_attention)

    # Spatial attention
    spatial_avg = layers.Lambda(lambda x: tf.reduce_mean(x, axis=-1, keepdims=True))(input_tensor)
    spatial_max = layers.Lambda(lambda x: tf.reduce_max(x, axis=-1, keepdims=True))(input_tensor)

    spatial_concat = layers.Concatenate(axis=-1)([spatial_avg, spatial_max])
    spatial_conv = layers.Conv2D(filters=num_heads, kernel_size=3, padding='same', activation='sigmoid')(spatial_concat)

    spatial_attention = layers.Lambda(lambda x: tf.split(x, num_heads, axis=-1))(spatial_conv)

    attention = layers.Add()([channel_attention] + spatial_attention)
    attention = layers.Conv2D(filters=1, kernel_size=3, padding='same', activation='sigmoid')(attention)

    # Apply attention
    attention_map = layers.Concatenate()([input_tensor, attention])
    attention_map = BatchNormalization()(attention_map)
    attention_map = Dropout(0.02)(attention_map)

    # Feature maps
    feature_maps = layers.Concatenate()([input_tensor,  attention_map]) # Testing Phase

    return feature_maps, attention_map

def cbam_block(input_tensor):
    feature_maps, attention_map = multihead_attention(input_tensor)
    return feature_maps, attention_map

# %%
from tensorflow.keras.layers import Lambda, DepthwiseConv2D, BatchNormalization, Dropout, Reshape, UpSampling2D, Multiply

# %%
#creating model
from tensorflow.keras.applications import Xception
def create_model():
    base_model = Xception(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))
    x = base_model.output
    x = BatchNormalization()(x)
    x = Dropout(0.02)(x)

    x = SeparableConv2D(512, kernel_size=(3, 3), activation='sigmoid',
                        depthwise_initializer='he_normal', pointwise_initializer='he_normal',
                        depthwise_regularizer=tf.keras.regularizers.l2(l2_reg),
                        pointwise_regularizer=tf.keras.regularizers.l2(l2_reg),
                        padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.02)(x)

    # CBAM block
    feature_maps, attention_map = cbam_block(x)
    feature_maps = BatchNormalization()(feature_maps)
    x = Dropout(0.02)(feature_maps)

    # GlobalAveragePooling2D block
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.02)(x)

    preds = Dense(units=num_classes, activation='softmax')(x)
    model = tf.keras.Model(inputs=base_model.input, outputs=preds)
    
    for layer in model.layers:
        layer.trainable = True
    
    return model

# %%
#Cosine Annealing Scheduler for scheduler for snapshot
import numpy as np
import tensorflow as tf
from tensorflow.keras.callbacks import Callback

class CosineAnnealingScheduler(Callback):
    def __init__(self, initial_lr, T_max, eta_min=0, verbose=0):
        super().__init__()
        self.initial_lr = initial_lr
        self.T_max = T_max
        self.eta_min = eta_min
        self.verbose = verbose

    def on_epoch_begin(self, epoch, logs=None):
        lr = self.calculate_lr(epoch)
        if self.verbose > 0:
            print(f'\nEpoch {epoch+1}: Learning rate is {lr:.6f}.')
        self.model.optimizer.learning_rate = lr  # Directly set the learning rate

    def calculate_lr(self, epoch):
        cos_inner = np.pi * (epoch % self.T_max)
        cos_inner /= self.T_max
        cos_out = np.cos(cos_inner) + 1
        return self.eta_min + ((self.initial_lr - self.eta_min) * cos_out) / 2


initial_learning_rate = 0.0001  
max_epochs = num_epochs_per_snapshot
max_epochs2 = final_epoch
min_learning_rate = 0.000001 

scheduler = CosineAnnealingScheduler(initial_learning_rate, T_max=max_epochs, 
                                     eta_min=min_learning_rate, verbose=1)

# %%
# Custom Dominant Strategy Loss function
class DominantStrategyLoss(tf.keras.losses.Loss):
    def __init__(self, lambda_reg=0.1):
        super(DominantStrategyLoss, self).__init__()
        self.lambda_reg = lambda_reg

    def call(self, y_true, y_pred):
        # Compute per-class cross-entropy loss
        per_class_losses = tf.keras.losses.categorical_crossentropy(y_true, y_pred)

        # Compute dominant strategies (e.g., using class accuracy)
        dominant_strategies = y_true  # Placeholder implementation: assuming the dominant strategy is the one-hot encoded label

        # Compute Kullback-Leibler divergence between predicted and dominant strategies
        kl_divergences = tf.keras.losses.KLDivergence()(y_pred, dominant_strategies)

        # Compute total loss
        total_loss = tf.reduce_mean(per_class_losses) + self.lambda_reg * tf.reduce_mean(kl_divergences)

        return total_loss

loss_function = DominantStrategyLoss(lambda_reg=0.1)

# %%
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import AUC, Precision, Recall, MeanSquaredError, Accuracy, TruePositives, TrueNegatives, FalsePositives, FalseNegatives, AUC, Precision, Recall, F1Score
from numpy import average

def snapshot_ensemble(train_generator, val_generator, num_snapshots, num_epochs_per_snapshot):
    
    ensemble_models = []
    snapshot_weights = []
    validation_accuracies = [] 
    test_accuracies = []  # To store test accuracy of each snapshot
    
    best_test_accuracy = 0
    best_snapshot_index = -1
    
    for snapshot in range(num_snapshots):
        print(f"Training snapshot {snapshot + 1}/{num_snapshots}")
        
        model = create_model()
        model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', 
                      metrics=['accuracy', 'mse', Precision(), Recall(), F1Score(), AUC(curve='ROC')])
        
        scheduler = CosineAnnealingScheduler(initial_learning_rate, T_max=max_epochs, 
                                             eta_min=min_learning_rate, verbose=2)
        
        history = model.fit(train_generator, epochs=num_epochs_per_snapshot, validation_data=val_generator, 
                            callbacks=[scheduler], verbose=1)
        
        evaluation = model.evaluate(test_generator)
        print("Test Loss:", evaluation[0])
        print("Test Accuracy:", evaluation[1])
        
        validation_accuracies.append(max(history.history['val_accuracy']))
        
        test_accuracies.append(evaluation[1])  # Assuming the second returned value is accuracy
        
        if evaluation[1] > best_test_accuracy:
            best_test_accuracy = evaluation[1]
            best_snapshot_index = snapshot
        
        snapshot_weights.append(model.get_weights())
        ensemble_models.append(model)
    
    # Adjusting weights based on validation accuracies and giving bonus to the best test accuracy
    adjusted_weights = np.array(validation_accuracies)
    adjusted_weights /= np.sum(adjusted_weights)  # Normalize
    adjusted_weights[best_snapshot_index] += 0.1  # Adding bonus weight, ensure it doesn't exceed 1 after normalization
    adjusted_weights /= np.sum(adjusted_weights)  # Re-normalize after bonus
    
    # Use adjusted weights for calculating the weighted average of model weights
    weighted_avg_weights = []
    for layer_index in range(len(snapshot_weights[0])):
        layer_weights = np.array([snapshot_weights[i][layer_index] for i in range(num_snapshots)])
        weighted_layer = np.average(layer_weights, axis=0, weights=adjusted_weights)
        weighted_avg_weights.append(weighted_layer)

    return ensemble_models, weighted_avg_weights

# %%
ensemble_models, weighted_avg_weights = snapshot_ensemble(train_generator, val_generator, 
                                                        num_snapshots, num_epochs_per_snapshot)
# Out:
# Training snapshot 1/3
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#
# Epoch 1: Learning rate is 0.000100.
# Epoch 1/12
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725036193.899562     124 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 106/419 ━━━━━━━━━━━━━━━━━━━━ 7:11 1s/step - accuracy: 0.4372 - auc: 0.8533 - f1_score: 0.3901 - loss: 11.9218 - mse: 0.0362 - precision: 0.6365 - recall: 0.3190
# /opt/conda/lib/python3.10/site-packages/PIL/Image.py:992: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1009s 2s/step - accuracy: 0.6405 - auc: 0.9404 - f1_score: 0.6114 - loss: 10.2584 - mse: 0.0245 - precision: 0.7670 - recall: 0.5637 - val_accuracy: 0.8760 - val_auc: 0.9944 - val_f1_score: 0.8898 - val_loss: 7.0297 - val_mse: 0.0257 - val_precision: 0.9910 - val_recall: 0.1802
#
# Epoch 2: Learning rate is 0.000098.
# Epoch 2/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 726s 2s/step - accuracy: 0.9073 - auc: 0.9954 - f1_score: 0.9090 - loss: 5.4109 - mse: 0.0073 - precision: 0.9223 - recall: 0.8933 - val_accuracy: 0.9575 - val_auc: 0.9986 - val_f1_score: 0.9618 - val_loss: 3.4545 - val_mse: 0.0034 - val_precision: 0.9653 - val_recall: 0.9513
#
# Epoch 3: Learning rate is 0.000093.
# Epoch 3/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 704s 2s/step - accuracy: 0.9393 - auc: 0.9969 - f1_score: 0.9417 - loss: 3.1269 - mse: 0.0049 - precision: 0.9475 - recall: 0.9314 - val_accuracy: 0.9741 - val_auc: 0.9995 - val_f1_score: 0.9773 - val_loss: 2.0632 - val_mse: 0.0021 - val_precision: 0.9774 - val_recall: 0.9714
#
# Epoch 4: Learning rate is 0.000086.
# Epoch 4/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 718s 2s/step - accuracy: 0.9575 - auc: 0.9985 - f1_score: 0.9612 - loss: 1.9116 - mse: 0.0034 - precision: 0.9638 - recall: 0.9533 - val_accuracy: 0.9761 - val_auc: 0.9988 - val_f1_score: 0.9793 - val_loss: 1.3471 - val_mse: 0.0020 - val_precision: 0.9769 - val_recall: 0.9750
#
# Epoch 5: Learning rate is 0.000075.
# Epoch 5/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 729s 2s/step - accuracy: 0.9664 - auc: 0.9985 - f1_score: 0.9677 - loss: 1.2655 - mse: 0.0027 - precision: 0.9712 - recall: 0.9633 - val_accuracy: 0.9896 - val_auc: 0.9998 - val_f1_score: 0.9897 - val_loss: 0.9018 - val_mse: 7.9910e-04 - val_precision: 0.9905 - val_recall: 0.9889
#
# Epoch 6: Learning rate is 0.000063.
# Epoch 6/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 696s 2s/step - accuracy: 0.9765 - auc: 0.9991 - f1_score: 0.9775 - loss: 0.8779 - mse: 0.0018 - precision: 0.9785 - recall: 0.9753 - val_accuracy: 0.9921 - val_auc: 0.9999 - val_f1_score: 0.9913 - val_loss: 0.6603 - val_mse: 6.2954e-04 - val_precision: 0.9930 - val_recall: 0.9917
#
# Epoch 7: Learning rate is 0.000051.
# Epoch 7/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 700s 2s/step - accuracy: 0.9812 - auc: 0.9995 - f1_score: 0.9821 - loss: 0.6563 - mse: 0.0016 - precision: 0.9824 - recall: 0.9793 - val_accuracy: 0.9918 - val_auc: 0.9997 - val_f1_score: 0.9930 - val_loss: 0.5203 - val_mse: 6.2593e-04 - val_precision: 0.9921 - val_recall: 0.9917
#
# Epoch 8: Learning rate is 0.000038.
# Epoch 8/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 718s 2s/step - accuracy: 0.9862 - auc: 0.9996 - f1_score: 0.9854 - loss: 0.5137 - mse: 0.0010 - precision: 0.9872 - recall: 0.9852 - val_accuracy: 0.9944 - val_auc: 0.9998 - val_f1_score: 0.9936 - val_loss: 0.4272 - val_mse: 4.4813e-04 - val_precision: 0.9944 - val_recall: 0.9944
#
# Epoch 9: Learning rate is 0.000026.
# Epoch 9/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 719s 2s/step - accuracy: 0.9903 - auc: 0.9999 - f1_score: 0.9897 - loss: 0.4258 - mse: 7.6440e-04 - precision: 0.9914 - recall: 0.9897 - val_accuracy: 0.9981 - val_auc: 0.9999 - val_f1_score: 0.9977 - val_loss: 0.3646 - val_mse: 1.4651e-04 - val_precision: 0.9981 - val_recall: 0.9981
#
# Epoch 10: Learning rate is 0.000015.
# Epoch 10/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 724s 2s/step - accuracy: 0.9943 - auc: 0.9998 - f1_score: 0.9922 - loss: 0.3701 - mse: 4.8061e-04 - precision: 0.9948 - recall: 0.9939 - val_accuracy: 0.9988 - val_auc: 1.0000 - val_f1_score: 0.9985 - val_loss: 0.3317 - val_mse: 9.5110e-05 - val_precision: 0.9988 - val_recall: 0.9988
#
# Epoch 11: Learning rate is 0.000008.
# Epoch 11/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 719s 2s/step - accuracy: 0.9938 - auc: 0.9998 - f1_score: 0.9928 - loss: 0.3421 - mse: 4.6810e-04 - precision: 0.9945 - recall: 0.9935 - val_accuracy: 0.9989 - val_auc: 1.0000 - val_f1_score: 0.9985 - val_loss: 0.3159 - val_mse: 8.9318e-05 - val_precision: 0.9989 - val_recall: 0.9989
#
# Epoch 12: Learning rate is 0.000003.
# Epoch 12/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 724s 2s/step - accuracy: 0.9964 - auc: 0.9999 - f1_score: 0.9954 - loss: 0.3235 - mse: 2.9609e-04 - precision: 0.9970 - recall: 0.9964 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_f1_score: 0.9986 - val_loss: 0.3100 - val_mse: 8.5200e-05 - val_precision: 0.9990 - val_recall: 0.9989
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 857ms/step - accuracy: 0.9323 - auc: 0.9873 - f1_score: 0.4401 - loss: 0.6457 - mse: 0.0058 - precision: 0.9390 - recall: 0.9304
# Test Loss: 0.7976795434951782
# Test Accuracy: 0.90450119972229
# Training snapshot 2/3
#
# Epoch 1: Learning rate is 0.000100.
# Epoch 1/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 793s 2s/step - accuracy: 0.6457 - auc_1: 0.9401 - f1_score: 0.6202 - loss: 10.2685 - mse: 0.0248 - precision_1: 0.7611 - recall_1: 0.5639 - val_accuracy: 0.8189 - val_auc_1: 0.9896 - val_f1_score: 0.8550 - val_loss: 7.1772 - val_mse: 0.0284 - val_precision_1: 0.9895 - val_recall_1: 0.1201
#
# Epoch 2: Learning rate is 0.000098.
# Epoch 2/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 764s 2s/step - accuracy: 0.8986 - auc_1: 0.9948 - f1_score: 0.9011 - loss: 5.4480 - mse: 0.0078 - precision_1: 0.9190 - recall_1: 0.8829 - val_accuracy: 0.9412 - val_auc_1: 0.9973 - val_f1_score: 0.9450 - val_loss: 3.5171 - val_mse: 0.0047 - val_precision_1: 0.9486 - val_recall_1: 0.9359
#
# Epoch 3: Learning rate is 0.000093.
# Epoch 3/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 724s 2s/step - accuracy: 0.9422 - auc_1: 0.9975 - f1_score: 0.9434 - loss: 3.1340 - mse: 0.0046 - precision_1: 0.9497 - recall_1: 0.9353 - val_accuracy: 0.9779 - val_auc_1: 0.9993 - val_f1_score: 0.9804 - val_loss: 2.0685 - val_mse: 0.0018 - val_precision_1: 0.9792 - val_recall_1: 0.9765
#
# Epoch 4: Learning rate is 0.000086.
# Epoch 4/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 746s 2s/step - accuracy: 0.9545 - auc_1: 0.9980 - f1_score: 0.9590 - loss: 1.9367 - mse: 0.0036 - precision_1: 0.9604 - recall_1: 0.9502 - val_accuracy: 0.9616 - val_auc_1: 0.9982 - val_f1_score: 0.9662 - val_loss: 1.4000 - val_mse: 0.0031 - val_precision_1: 0.9640 - val_recall_1: 0.9596
#
# Epoch 5: Learning rate is 0.000075.
# Epoch 5/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 736s 2s/step - accuracy: 0.9683 - auc_1: 0.9990 - f1_score: 0.9712 - loss: 1.2675 - mse: 0.0026 - precision_1: 0.9710 - recall_1: 0.9648 - val_accuracy: 0.9841 - val_auc_1: 0.9995 - val_f1_score: 0.9860 - val_loss: 0.9291 - val_mse: 0.0014 - val_precision_1: 0.9847 - val_recall_1: 0.9832
#
# Epoch 6: Learning rate is 0.000063.
# Epoch 6/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 681s 2s/step - accuracy: 0.9770 - auc_1: 0.9990 - f1_score: 0.9783 - loss: 0.8877 - mse: 0.0018 - precision_1: 0.9788 - recall_1: 0.9755 - val_accuracy: 0.9919 - val_auc_1: 0.9998 - val_f1_score: 0.9925 - val_loss: 0.6706 - val_mse: 6.9469e-04 - val_precision_1: 0.9924 - val_recall_1: 0.9907
#
# Epoch 7: Learning rate is 0.000051.
# Epoch 7/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 666s 2s/step - accuracy: 0.9794 - auc_1: 0.9996 - f1_score: 0.9799 - loss: 0.6621 - mse: 0.0016 - precision_1: 0.9816 - recall_1: 0.9781 - val_accuracy: 0.9951 - val_auc_1: 0.9998 - val_f1_score: 0.9953 - val_loss: 0.5182 - val_mse: 3.8409e-04 - val_precision_1: 0.9954 - val_recall_1: 0.9950
#
# Epoch 8: Learning rate is 0.000038.
# Epoch 8/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 675s 2s/step - accuracy: 0.9850 - auc_1: 0.9995 - f1_score: 0.9848 - loss: 0.5231 - mse: 0.0011 - precision_1: 0.9862 - recall_1: 0.9835 - val_accuracy: 0.9975 - val_auc_1: 0.9999 - val_f1_score: 0.9977 - val_loss: 0.4272 - val_mse: 2.2373e-04 - val_precision_1: 0.9978 - val_recall_1: 0.9974
#
# Epoch 9: Learning rate is 0.000026.
# Epoch 9/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 704s 2s/step - accuracy: 0.9912 - auc_1: 0.9999 - f1_score: 0.9897 - loss: 0.4327 - mse: 7.5953e-04 - precision_1: 0.9924 - recall_1: 0.9905 - val_accuracy: 0.9983 - val_auc_1: 1.0000 - val_f1_score: 0.9982 - val_loss: 0.3713 - val_mse: 1.5339e-04 - val_precision_1: 0.9983 - val_recall_1: 0.9982
#
# Epoch 10: Learning rate is 0.000015.
# Epoch 10/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 702s 2s/step - accuracy: 0.9930 - auc_1: 0.9998 - f1_score: 0.9923 - loss: 0.3814 - mse: 5.9935e-04 - precision_1: 0.9932 - recall_1: 0.9921 - val_accuracy: 0.9988 - val_auc_1: 1.0000 - val_f1_score: 0.9989 - val_loss: 0.3388 - val_mse: 9.1744e-05 - val_precision_1: 0.9988 - val_recall_1: 0.9988
#
# Epoch 11: Learning rate is 0.000008.
# Epoch 11/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 750s 2s/step - accuracy: 0.9942 - auc_1: 0.9998 - f1_score: 0.9936 - loss: 0.3511 - mse: 5.1129e-04 - precision_1: 0.9944 - recall_1: 0.9936 - val_accuracy: 0.9991 - val_auc_1: 1.0000 - val_f1_score: 0.9990 - val_loss: 0.3227 - val_mse: 7.6537e-05 - val_precision_1: 0.9991 - val_recall_1: 0.9991
#
# Epoch 12: Learning rate is 0.000003.
# Epoch 12/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 690s 2s/step - accuracy: 0.9947 - auc_1: 1.0000 - f1_score: 0.9932 - loss: 0.3350 - mse: 4.3317e-04 - precision_1: 0.9956 - recall_1: 0.9942 - val_accuracy: 0.9992 - val_auc_1: 1.0000 - val_f1_score: 0.9991 - val_loss: 0.3168 - val_mse: 7.3051e-05 - val_precision_1: 0.9992 - val_recall_1: 0.9992
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 44s 430ms/step - accuracy: 0.9313 - auc_1: 0.9861 - f1_score: 0.4386 - loss: 0.6606 - mse: 0.0058 - precision_1: 0.9355 - recall_1: 0.9306
# Test Loss: 0.850942075252533
# Test Accuracy: 0.897506058216095
# Training snapshot 3/3
#
# Epoch 1: Learning rate is 0.000100.
# Epoch 1/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 765s 2s/step - accuracy: 0.6515 - auc_2: 0.9396 - f1_score: 0.6192 - loss: 10.2334 - mse: 0.0241 - precision_2: 0.7761 - recall_2: 0.5730 - val_accuracy: 0.9145 - val_auc_2: 0.9968 - val_f1_score: 0.9199 - val_loss: 6.9865 - val_mse: 0.0250 - val_precision_2: 0.9992 - val_recall_2: 0.1888
#
# Epoch 2: Learning rate is 0.000098.
# Epoch 2/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 701s 2s/step - accuracy: 0.9011 - auc_2: 0.9954 - f1_score: 0.9041 - loss: 5.3989 - mse: 0.0076 - precision_2: 0.9202 - recall_2: 0.8868 - val_accuracy: 0.9535 - val_auc_2: 0.9985 - val_f1_score: 0.9588 - val_loss: 3.4618 - val_mse: 0.0036 - val_precision_2: 0.9594 - val_recall_2: 0.9483
#
# Epoch 3: Learning rate is 0.000093.
# Epoch 3/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 675s 2s/step - accuracy: 0.9388 - auc_2: 0.9975 - f1_score: 0.9440 - loss: 3.1316 - mse: 0.0048 - precision_2: 0.9477 - recall_2: 0.9330 - val_accuracy: 0.9717 - val_auc_2: 0.9992 - val_f1_score: 0.9735 - val_loss: 2.1003 - val_mse: 0.0022 - val_precision_2: 0.9744 - val_recall_2: 0.9685
#
# Epoch 4: Learning rate is 0.000086.
# Epoch 4/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 680s 2s/step - accuracy: 0.9544 - auc_2: 0.9980 - f1_score: 0.9563 - loss: 1.9538 - mse: 0.0035 - precision_2: 0.9614 - recall_2: 0.9497 - val_accuracy: 0.9782 - val_auc_2: 0.9993 - val_f1_score: 0.9801 - val_loss: 1.3738 - val_mse: 0.0018 - val_precision_2: 0.9794 - val_recall_2: 0.9774
#
# Epoch 5: Learning rate is 0.000075.
# Epoch 5/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 692s 2s/step - accuracy: 0.9702 - auc_2: 0.9991 - f1_score: 0.9716 - loss: 1.2900 - mse: 0.0024 - precision_2: 0.9732 - recall_2: 0.9673 - val_accuracy: 0.9904 - val_auc_2: 0.9997 - val_f1_score: 0.9905 - val_loss: 0.9353 - val_mse: 7.8322e-04 - val_precision_2: 0.9911 - val_recall_2: 0.9901
#
# Epoch 6: Learning rate is 0.000063.
# Epoch 6/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 724s 2s/step - accuracy: 0.9752 - auc_2: 0.9992 - f1_score: 0.9775 - loss: 0.9158 - mse: 0.0020 - precision_2: 0.9783 - recall_2: 0.9734 - val_accuracy: 0.9903 - val_auc_2: 0.9997 - val_f1_score: 0.9914 - val_loss: 0.7002 - val_mse: 8.2659e-04 - val_precision_2: 0.9906 - val_recall_2: 0.9898
#
# Epoch 7: Learning rate is 0.000051.
# Epoch 7/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 674s 2s/step - accuracy: 0.9838 - auc_2: 0.9994 - f1_score: 0.9828 - loss: 0.6822 - mse: 0.0013 - precision_2: 0.9851 - recall_2: 0.9825 - val_accuracy: 0.9935 - val_auc_2: 0.9999 - val_f1_score: 0.9945 - val_loss: 0.5431 - val_mse: 5.2295e-04 - val_precision_2: 0.9936 - val_recall_2: 0.9933
#
# Epoch 8: Learning rate is 0.000038.
# Epoch 8/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 676s 2s/step - accuracy: 0.9880 - auc_2: 0.9996 - f1_score: 0.9880 - loss: 0.5408 - mse: 0.0010 - precision_2: 0.9893 - recall_2: 0.9872 - val_accuracy: 0.9962 - val_auc_2: 1.0000 - val_f1_score: 0.9963 - val_loss: 0.4449 - val_mse: 2.7893e-04 - val_precision_2: 0.9965 - val_recall_2: 0.9962
#
# Epoch 9: Learning rate is 0.000026.
# Epoch 9/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 674s 2s/step - accuracy: 0.9908 - auc_2: 0.9998 - f1_score: 0.9911 - loss: 0.4498 - mse: 7.3336e-04 - precision_2: 0.9920 - recall_2: 0.9902 - val_accuracy: 0.9981 - val_auc_2: 0.9999 - val_f1_score: 0.9982 - val_loss: 0.3882 - val_mse: 1.6940e-04 - val_precision_2: 0.9981 - val_recall_2: 0.9980
#
# Epoch 10: Learning rate is 0.000015.
# Epoch 10/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 697s 2s/step - accuracy: 0.9935 - auc_2: 0.9998 - f1_score: 0.9934 - loss: 0.3951 - mse: 5.4286e-04 - precision_2: 0.9941 - recall_2: 0.9925 - val_accuracy: 0.9984 - val_auc_2: 1.0000 - val_f1_score: 0.9985 - val_loss: 0.3539 - val_mse: 1.2942e-04 - val_precision_2: 0.9984 - val_recall_2: 0.9983
#
# Epoch 11: Learning rate is 0.000008.
# Epoch 11/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 687s 2s/step - accuracy: 0.9951 - auc_2: 1.0000 - f1_score: 0.9947 - loss: 0.3594 - mse: 3.6190e-04 - precision_2: 0.9957 - recall_2: 0.9949 - val_accuracy: 0.9983 - val_auc_2: 1.0000 - val_f1_score: 0.9984 - val_loss: 0.3371 - val_mse: 1.2156e-04 - val_precision_2: 0.9983 - val_recall_2: 0.9983
#
# Epoch 12: Learning rate is 0.000003.
# Epoch 12/12
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 674s 2s/step - accuracy: 0.9955 - auc_2: 0.9999 - f1_score: 0.9949 - loss: 0.3459 - mse: 3.5242e-04 - precision_2: 0.9958 - recall_2: 0.9953 - val_accuracy: 0.9985 - val_auc_2: 1.0000 - val_f1_score: 0.9986 - val_loss: 0.3309 - val_mse: 1.1714e-04 - val_precision_2: 0.9985 - val_recall_2: 0.9985
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 44s 432ms/step - accuracy: 0.9250 - auc_2: 0.9857 - f1_score: 0.4368 - loss: 0.7153 - mse: 0.0066 - precision_2: 0.9299 - recall_2: 0.9244
# Test Loss: 0.8656806945800781
# Test Accuracy: 0.900547444820404

# %%
#Creating final model with average of three snapshot weights 
final_model = create_model() 

checkpoint = ModelCheckpoint('SSE_Dnet121_juivcd.weights.h5', monitor='val_accuracy', 
                             save_best_only = True, save_weights_only = True, mode ='max', verbose = 1)

scheduler = CosineAnnealingScheduler(initial_learning_rate, T_max=max_epochs2, 
                                     eta_min=min_learning_rate, verbose=1)
        
final_model.compile(optimizer=Adam(learning_rate = 0.0001), loss=loss_function, 
                      metrics=['accuracy', 'mse', Precision(), Recall(), F1Score(), AUC(curve='ROC')])  
        
final_model.set_weights(weighted_avg_weights)

history = final_model.fit(train_generator, epochs=final_epoch, validation_data=val_generator, 
                  callbacks=[checkpoint, scheduler], verbose=1)

evaluation = final_model.evaluate(test_generator)

print("Test Loss:", evaluation[0])
print("Test Accuracy:", evaluation[1])
# Out:
# Epoch 1: Learning rate is 0.000100.
# Epoch 1/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9701 - auc_3: 0.9987 - f1_score: 0.9727 - loss: 0.3397 - mse: 0.0031 - precision_3: 0.9755 - recall_3: 0.9455
# Epoch 1: val_accuracy improved from -inf to 0.97458, saving model to SSE_Dnet121_juivcd.weights.h5
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 767s 2s/step - accuracy: 0.9701 - auc_3: 0.9987 - f1_score: 0.9727 - loss: 0.3396 - mse: 0.0031 - precision_3: 0.9755 - recall_3: 0.9456 - val_accuracy: 0.9746 - val_auc_3: 0.9969 - val_f1_score: 0.9785 - val_loss: 0.2463 - val_mse: 0.0022 - val_precision_3: 0.9757 - val_recall_3: 0.9731
#
# Epoch 2: Learning rate is 0.000098.
# Epoch 2/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 997ms/step - accuracy: 0.9789 - auc_3: 0.9987 - f1_score: 0.9804 - loss: 0.2038 - mse: 0.0018 - precision_3: 0.9797 - recall_3: 0.9770
# Epoch 2: val_accuracy improved from 0.97458 to 0.98968, saving model to SSE_Dnet121_juivcd.weights.h5
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 716s 2s/step - accuracy: 0.9788 - auc_3: 0.9987 - f1_score: 0.9804 - loss: 0.2038 - mse: 0.0018 - precision_3: 0.9797 - recall_3: 0.9770 - val_accuracy: 0.9897 - val_auc_3: 0.9994 - val_f1_score: 0.9895 - val_loss: 0.1268 - val_mse: 8.6667e-04 - val_precision_3: 0.9901 - val_recall_3: 0.9893
#
# Epoch 3: Learning rate is 0.000091.
# Epoch 3/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 977ms/step - accuracy: 0.9791 - auc_3: 0.9989 - f1_score: 0.9775 - loss: 0.1793 - mse: 0.0017 - precision_3: 0.9815 - recall_3: 0.9770
# Epoch 3: val_accuracy improved from 0.98968 to 0.99402, saving model to SSE_Dnet121_juivcd.weights.h5
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 704s 2s/step - accuracy: 0.9791 - auc_3: 0.9989 - f1_score: 0.9775 - loss: 0.1793 - mse: 0.0017 - precision_3: 0.9815 - recall_3: 0.9770 - val_accuracy: 0.9940 - val_auc_3: 0.9996 - val_f1_score: 0.9938 - val_loss: 0.0936 - val_mse: 5.3260e-04 - val_precision_3: 0.9942 - val_recall_3: 0.9938
#
# Epoch 4: Learning rate is 0.000080.
# Epoch 4/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 985ms/step - accuracy: 0.9898 - auc_3: 0.9995 - f1_score: 0.9882 - loss: 0.1142 - mse: 8.5402e-04 - precision_3: 0.9906 - recall_3: 0.9886
# Epoch 4: val_accuracy improved from 0.99402 to 0.99656, saving model to SSE_Dnet121_juivcd.weights.h5
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 699s 2s/step - accuracy: 0.9898 - auc_3: 0.9995 - f1_score: 0.9882 - loss: 0.1142 - mse: 8.5417e-04 - precision_3: 0.9906 - recall_3: 0.9886 - val_accuracy: 0.9966 - val_auc_3: 0.9998 - val_f1_score: 0.9968 - val_loss: 0.0672 - val_mse: 3.1282e-04 - val_precision_3: 0.9967 - val_recall_3: 0.9963
#
# Epoch 5: Learning rate is 0.000066.
# Epoch 5/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9889 - auc_3: 0.9995 - f1_score: 0.9889 - loss: 0.1029 - mse: 8.8096e-04 - precision_3: 0.9906 - recall_3: 0.9882
# Epoch 5: val_accuracy improved from 0.99656 to 0.99664, saving model to SSE_Dnet121_juivcd.weights.h5
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 728s 2s/step - accuracy: 0.9889 - auc_3: 0.9995 - f1_score: 0.9889 - loss: 0.1029 - mse: 8.8093e-04 - precision_3: 0.9906 - recall_3: 0.9882 - val_accuracy: 0.9966 - val_auc_3: 0.9998 - val_f1_score: 0.9966 - val_loss: 0.0568 - val_mse: 2.8477e-04 - val_precision_3: 0.9967 - val_recall_3: 0.9966
#
# Epoch 6: Learning rate is 0.000051.
# Epoch 6/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 978ms/step - accuracy: 0.9917 - auc_3: 1.0000 - f1_score: 0.9891 - loss: 0.0830 - mse: 7.1837e-04 - precision_3: 0.9927 - recall_3: 0.9907
# Epoch 6: val_accuracy improved from 0.99664 to 0.99798, saving model to SSE_Dnet121_juivcd.weights.h5
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 710s 2s/step - accuracy: 0.9917 - auc_3: 1.0000 - f1_score: 0.9891 - loss: 0.0829 - mse: 7.1815e-04 - precision_3: 0.9927 - recall_3: 0.9907 - val_accuracy: 0.9980 - val_auc_3: 0.9999 - val_f1_score: 0.9980 - val_loss: 0.0446 - val_mse: 1.6856e-04 - val_precision_3: 0.9981 - val_recall_3: 0.9979
#
# Epoch 7: Learning rate is 0.000035.
# Epoch 7/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 983ms/step - accuracy: 0.9936 - auc_3: 0.9996 - f1_score: 0.9924 - loss: 0.0666 - mse: 5.3244e-04 - precision_3: 0.9940 - recall_3: 0.9922
# Epoch 7: val_accuracy improved from 0.99798 to 0.99910, saving model to SSE_Dnet121_juivcd.weights.h5
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 712s 2s/step - accuracy: 0.9936 - auc_3: 0.9996 - f1_score: 0.9924 - loss: 0.0666 - mse: 5.3213e-04 - precision_3: 0.9940 - recall_3: 0.9922 - val_accuracy: 0.9991 - val_auc_3: 0.9999 - val_f1_score: 0.9989 - val_loss: 0.0337 - val_mse: 7.1386e-05 - val_precision_3: 0.9992 - val_recall_3: 0.9991
#
# Epoch 8: Learning rate is 0.000021.
# Epoch 8/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9955 - auc_3: 1.0000 - f1_score: 0.9954 - loss: 0.0510 - mse: 3.5618e-04 - precision_3: 0.9960 - recall_3: 0.9950
# Epoch 8: val_accuracy improved from 0.99910 to 0.99940, saving model to SSE_Dnet121_juivcd.weights.h5
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 745s 2s/step - accuracy: 0.9955 - auc_3: 1.0000 - f1_score: 0.9954 - loss: 0.0510 - mse: 3.5598e-04 - precision_3: 0.9960 - recall_3: 0.9950 - val_accuracy: 0.9994 - val_auc_3: 1.0000 - val_f1_score: 0.9993 - val_loss: 0.0298 - val_mse: 5.5932e-05 - val_precision_3: 0.9994 - val_recall_3: 0.9994
#
# Epoch 9: Learning rate is 0.000010.
# Epoch 9/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9965 - auc_3: 0.9999 - f1_score: 0.9958 - loss: 0.0431 - mse: 2.5034e-04 - precision_3: 0.9968 - recall_3: 0.9964
# Epoch 9: val_accuracy did not improve from 0.99940
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 738s 2s/step - accuracy: 0.9965 - auc_3: 0.9999 - f1_score: 0.9958 - loss: 0.0431 - mse: 2.5026e-04 - precision_3: 0.9968 - recall_3: 0.9964 - val_accuracy: 0.9994 - val_auc_3: 1.0000 - val_f1_score: 0.9993 - val_loss: 0.0274 - val_mse: 4.7463e-05 - val_precision_3: 0.9994 - val_recall_3: 0.9994
#
# Epoch 10: Learning rate is 0.000003.
# Epoch 10/10
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 982ms/step - accuracy: 0.9967 - auc_3: 0.9999 - f1_score: 0.9952 - loss: 0.0415 - mse: 2.3921e-04 - precision_3: 0.9969 - recall_3: 0.9963
# Epoch 10: val_accuracy did not improve from 0.99940
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 710s 2s/step - accuracy: 0.9967 - auc_3: 0.9999 - f1_score: 0.9952 - loss: 0.0415 - mse: 2.3915e-04 - precision_3: 0.9969 - recall_3: 0.9963 - val_accuracy: 0.9994 - val_auc_3: 1.0000 - val_f1_score: 0.9993 - val_loss: 0.0267 - val_mse: 4.6886e-05 - val_precision_3: 0.9994 - val_recall_3: 0.9993
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 57s 557ms/step - accuracy: 0.9372 - auc_3: 0.9869 - f1_score: 0.4420 - loss: 0.4767 - mse: 0.0055 - precision_3: 0.9417 - recall_3: 0.9345
# Test Loss: 0.6887174844741821
# Test Accuracy: 0.9096715450286865

# %%
#training accuracy vs epochs graphs and traing validation loss vs epochs
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, label='Train Accuracy')
ax[0].plot(val_accuracy, label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, label='Train Loss')
ax[1].plot(val_loss, label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
import IPython
IPython.display.FileLink('SSE_Dnet121_juivcd.weights.h5')
# Out:
# /kaggle/working/SSE_Dnet121_juivcd.weights.h5

# %%
final_model.load_weights("/kaggle/working/SSE_Dnet121_juivcd.weights.h5")

# %%
evaluation = final_model.evaluate(test_generator)

print("Test Loss:", evaluation[0])
print("Test Accuracy:", evaluation[1])
# Out:
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 43s 416ms/step - accuracy: 0.9367 - auc_3: 0.9856 - f1_score: 0.4412 - loss: 0.5012 - mse: 0.0056 - precision_3: 0.9408 - recall_3: 0.9328
# Test Loss: 0.7252270579338074
# Test Accuracy: 0.9051094651222229

# %%
train_class_names = sorted(list(train_generator.class_indices.keys()))

test_class_names = sorted(list(test_generator.class_indices.keys()))

assert train_class_names == test_class_names, "Class names in train and test datasets don't match!"

labels = train_class_names

# %%
# Assuming you have the ground truth labels for the test data in a variable called 'true_labels'
true_labels = test_generator.classes

# Generate predictions for the test data
predictions = final_model.predict(test_generator)
predicted_labels = np.argmax(predictions, axis=1)

# Define class labels (replace with your actual class names)
labels = train_class_names  # Replace with your class names

# Generate the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
# Out:
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 48s 439ms/step

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Assuming you have predicted probabilities and true labels for multi-class classification
true_labels = test_generator.classes
predictions = final_model.predict(test_generator)

# Perform t-SNE dimensionality reduction on predicted probabilities
tsne = TSNE(n_components=2, random_state=42)
predicted_tsne = tsne.fit_transform(predictions)

# Plot t-SNE visualization
plt.figure(figsize=(15, 12))
plt.scatter(predicted_tsne[:, 0], predicted_tsne[:, 1], c=true_labels, cmap='viridis')
plt.colorbar(label='Classes')
plt.title('t-SNE Visualization of Predicted Probabilities')
plt.grid(True)
plt.show()
# Out:
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 405ms/step

# %%
from sklearn.metrics import precision_recall_curve

# Assuming you have true labels and predicted probabilities for each class
true_labels = test_generator.classes  # Actual labels
predictions = final_model.predict(test_generator)  # Predicted probabilities for each class

# For each class, calculate precision and recall
precision = dict()
recall = dict()
for i in range(num_classes):  # Replace 'num_classes' with the number of classes (196)
    precision[i], recall[i], _ = precision_recall_curve(true_labels == i, predictions[:, i])

# Plot precision-recall curve for each class
plt.figure(figsize=(10, 8))
for i in range(num_classes):
    plt.plot(recall[i], precision[i], label=f'Class {i}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve for Each Class')
plt.legend()
plt.show()
# Out:
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 406ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import numpy as np
import pandas as pd

# Assuming you have true labels and predicted labels for 196 classes
true_labels = test_generator.classes  # Actual labels
predictions = final_model.predict(test_generator)  # Predicted probabilities or class labels

# Convert predicted probabilities to class labels if necessary
predicted_labels = np.argmax(predictions, axis=1)  # Convert probabilities to class labels

# Create a confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Calculate aggregated metrics
classification_rep = classification_report(true_labels, predicted_labels, output_dict=True)
metrics_df = pd.DataFrame(classification_rep).transpose()

# Plot the confusion matrix using seaborn heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=True, yticklabels=True)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix: True vs Predicted Labels')
plt.show()

# Display aggregated metrics
print(metrics_df)
# Out:
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 410ms/step
#               precision    recall  f1-score      support
# 0              1.000000  0.990196  0.995074   204.000000
# 1              0.940299  0.878049  0.908108   287.000000
# 2              0.938028  0.997006  0.966618   334.000000
# 3              0.952756  0.991803  0.971888   122.000000
# 4              0.923077  0.940299  0.931608   268.000000
# 5              0.798206  0.927083  0.857831   384.000000
# 6              0.902439  0.698113  0.787234   106.000000
# 7              0.909910  0.821138  0.863248   123.000000
# 8              0.980392  0.980392  0.980392    51.000000
# 9              0.977099  0.969697  0.973384   132.000000
# 10             0.803922  0.953488  0.872340    43.000000
# 11             0.921687  0.900000  0.910714   170.000000
# 12             0.818792  0.762500  0.789644   160.000000
# 13             0.837838  0.939394  0.885714    99.000000
# 14             0.955556  1.000000  0.977273    86.000000
# 15             0.901163  0.906433  0.903790   342.000000
# 16             0.917355  0.909836  0.913580   122.000000
# 17             0.928571  0.829787  0.876404    47.000000
# 18             0.904762  0.730769  0.808511   208.000000
# accuracy       0.905109  0.905109  0.905109     0.905109
# macro avg      0.911150  0.901368  0.903861  3288.000000
# weighted avg   0.907296  0.905109  0.904062  3288.000000

# %%
# Extracting metrics using classification_report
metrics = classification_report(true_labels, predicted_labels, output_dict=True)

# %%
# Calculate average metrics for all classes
avg_precision = metrics['macro avg']['precision']
avg_recall = metrics['macro avg']['recall']
avg_f1_score = metrics['macro avg']['f1-score']

print("Average Precision:", avg_precision)
print("Average Recall:", avg_recall)
print("Average F1-Score:", avg_f1_score)
# Out:
# Average Precision: 0.9111500664287311
# Average Recall: 0.9013675843330106
# Average F1-Score: 0.9038608733164681

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing import image

# Display
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
final_model.save('finalmodel_cmanxception.weights.h5.keras')

# %%
final_model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 220, 220,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 109, 109,  │        864 │ input_layer_3[0]… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_bn     │ (None, 109, 109,  │        128 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_act    │ (None, 109, 109,  │          0 │ block1_conv1_bn[… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 107, 107,  │     18,432 │ block1_conv1_act… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_bn     │ (None, 107, 107,  │        256 │ block1_conv2[0][… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_act    │ (None, 107, 107,  │          0 │ block1_conv2_bn[… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1     │ (None, 107, 107,  │      8,768 │ block1_conv2_act… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1_bn  │ (None, 107, 107,  │        512 │ block2_sepconv1[… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_act │ (None, 107, 107,  │          0 │ block2_sepconv1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2     │ (None, 107, 107,  │     17,536 │ block2_sepconv2_… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_bn  │ (None, 107, 107,  │        512 │ block2_sepconv2[… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 54, 54,    │      8,192 │ block1_conv2_act… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 54, 54,    │          0 │ block2_sepconv2_… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 54, 54,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_36 (Add)        │ (None, 54, 54,    │          0 │ block2_pool[0][0… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_act │ (None, 54, 54,    │          0 │ add_36[0][0]      │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1     │ (None, 54, 54,    │     33,920 │ block3_sepconv1_… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_bn  │ (None, 54, 54,    │      1,024 │ block3_sepconv1[… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_act │ (None, 54, 54,    │          0 │ block3_sepconv1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2     │ (None, 54, 54,    │     67,840 │ block3_sepconv2_… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_bn  │ (None, 54, 54,    │      1,024 │ block3_sepconv2[… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 27, 27,    │     32,768 │ add_36[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 27, 27,    │          0 │ block3_sepconv2_… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 27, 27,    │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_37 (Add)        │ (None, 27, 27,    │          0 │ block3_pool[0][0… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_act │ (None, 27, 27,    │          0 │ add_37[0][0]      │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1     │ (None, 27, 27,    │    188,672 │ block4_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_bn  │ (None, 27, 27,    │      2,912 │ block4_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_act │ (None, 27, 27,    │          0 │ block4_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2     │ (None, 27, 27,    │    536,536 │ block4_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_bn  │ (None, 27, 27,    │      2,912 │ block4_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 14, 14,    │    186,368 │ add_37[0][0]      │
# │                     │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_sepconv2_… │
# │ (MaxPooling2D)      │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,912 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_38 (Add)        │ (None, 14, 14,    │          0 │ block4_pool[0][0… │
# │                     │ 728)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_act │ (None, 14, 14,    │          0 │ add_38[0][0]      │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1     │ (None, 14, 14,    │    536,536 │ block5_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block5_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_act │ (None, 14, 14,    │          0 │ block5_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2     │ (None, 14, 14,    │    536,536 │ block5_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block5_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_act │ (None, 14, 14,    │          0 │ block5_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3     │ (None, 14, 14,    │    536,536 │ block5_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block5_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_39 (Add)        │ (None, 14, 14,    │          0 │ block5_sepconv3_… │
# │                     │ 728)              │            │ add_38[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_act │ (None, 14, 14,    │          0 │ add_39[0][0]      │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1     │ (None, 14, 14,    │    536,536 │ block6_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block6_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_act │ (None, 14, 14,    │          0 │ block6_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2     │ (None, 14, 14,    │    536,536 │ block6_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block6_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_act │ (None, 14, 14,    │          0 │ block6_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3     │ (None, 14, 14,    │    536,536 │ block6_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block6_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_40 (Add)        │ (None, 14, 14,    │          0 │ block6_sepconv3_… │
# │                     │ 728)              │            │ add_39[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_act │ (None, 14, 14,    │          0 │ add_40[0][0]      │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1     │ (None, 14, 14,    │    536,536 │ block7_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block7_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_act │ (None, 14, 14,    │          0 │ block7_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2     │ (None, 14, 14,    │    536,536 │ block7_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block7_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_act │ (None, 14, 14,    │          0 │ block7_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3     │ (None, 14, 14,    │    536,536 │ block7_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block7_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_41 (Add)        │ (None, 14, 14,    │          0 │ block7_sepconv3_… │
# │                     │ 728)              │            │ add_40[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_act │ (None, 14, 14,    │          0 │ add_41[0][0]      │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1     │ (None, 14, 14,    │    536,536 │ block8_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block8_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_act │ (None, 14, 14,    │          0 │ block8_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2     │ (None, 14, 14,    │    536,536 │ block8_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block8_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_act │ (None, 14, 14,    │          0 │ block8_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3     │ (None, 14, 14,    │    536,536 │ block8_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block8_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_42 (Add)        │ (None, 14, 14,    │          0 │ block8_sepconv3_… │
# │                     │ 728)              │            │ add_41[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_act │ (None, 14, 14,    │          0 │ add_42[0][0]      │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1     │ (None, 14, 14,    │    536,536 │ block9_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block9_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_act │ (None, 14, 14,    │          0 │ block9_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2     │ (None, 14, 14,    │    536,536 │ block9_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block9_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_act │ (None, 14, 14,    │          0 │ block9_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3     │ (None, 14, 14,    │    536,536 │ block9_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block9_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_43 (Add)        │ (None, 14, 14,    │          0 │ block9_sepconv3_… │
# │                     │ 728)              │            │ add_42[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_a… │ (None, 14, 14,    │          0 │ add_43[0][0]      │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1    │ (None, 14, 14,    │    536,536 │ block10_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_bn │ (None, 14, 14,    │      2,912 │ block10_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_a… │ (None, 14, 14,    │          0 │ block10_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2    │ (None, 14, 14,    │    536,536 │ block10_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_bn │ (None, 14, 14,    │      2,912 │ block10_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_a… │ (None, 14, 14,    │          0 │ block10_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3    │ (None, 14, 14,    │    536,536 │ block10_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_bn │ (None, 14, 14,    │      2,912 │ block10_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_44 (Add)        │ (None, 14, 14,    │          0 │ block10_sepconv3… │
# │                     │ 728)              │            │ add_43[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_a… │ (None, 14, 14,    │          0 │ add_44[0][0]      │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1    │ (None, 14, 14,    │    536,536 │ block11_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_bn │ (None, 14, 14,    │      2,912 │ block11_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_a… │ (None, 14, 14,    │          0 │ block11_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2    │ (None, 14, 14,    │    536,536 │ block11_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_bn │ (None, 14, 14,    │      2,912 │ block11_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_a… │ (None, 14, 14,    │          0 │ block11_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3    │ (None, 14, 14,    │    536,536 │ block11_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_bn │ (None, 14, 14,    │      2,912 │ block11_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_45 (Add)        │ (None, 14, 14,    │          0 │ block11_sepconv3… │
# │                     │ 728)              │            │ add_44[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_a… │ (None, 14, 14,    │          0 │ add_45[0][0]      │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1    │ (None, 14, 14,    │    536,536 │ block12_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_bn │ (None, 14, 14,    │      2,912 │ block12_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_a… │ (None, 14, 14,    │          0 │ block12_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2    │ (None, 14, 14,    │    536,536 │ block12_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_bn │ (None, 14, 14,    │      2,912 │ block12_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_a… │ (None, 14, 14,    │          0 │ block12_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3    │ (None, 14, 14,    │    536,536 │ block12_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_bn │ (None, 14, 14,    │      2,912 │ block12_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_46 (Add)        │ (None, 14, 14,    │          0 │ block12_sepconv3… │
# │                     │ 728)              │            │ add_45[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_a… │ (None, 14, 14,    │          0 │ add_46[0][0]      │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1    │ (None, 14, 14,    │    536,536 │ block13_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_bn │ (None, 14, 14,    │      2,912 │ block13_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_a… │ (None, 14, 14,    │          0 │ block13_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2    │ (None, 14, 14,    │    752,024 │ block13_sepconv2… │
# │ (SeparableConv2D)   │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_bn │ (None, 14, 14,    │      4,096 │ block13_sepconv2… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 7, 7,      │    745,472 │ add_46[0][0]      │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_pool        │ (None, 7, 7,      │          0 │ block13_sepconv2… │
# │ (MaxPooling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7,      │      4,096 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_47 (Add)        │ (None, 7, 7,      │          0 │ block13_pool[0][… │
# │                     │ 1024)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1    │ (None, 7, 7,      │  1,582,080 │ add_47[0][0]      │
# │ (SeparableConv2D)   │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_bn │ (None, 7, 7,      │      6,144 │ block14_sepconv1… │
# │ (BatchNormalizatio… │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_a… │ (None, 7, 7,      │          0 │ block14_sepconv1… │
# │ (Activation)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2    │ (None, 7, 7,      │  3,159,552 │ block14_sepconv1… │
# │ (SeparableConv2D)   │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2_bn │ (None, 7, 7,      │      8,192 │ block14_sepconv2… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2_a… │ (None, 7, 7,      │          0 │ block14_sepconv2… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7,      │      8,192 │ block14_sepconv2… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 7, 7,      │          0 │ batch_normalizat… │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 7, 7, 512) │  1,067,520 │ dropout_9[0][0]   │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ dropout_10[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ global_average_p… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 512)       │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 19)        │      9,747 │ dropout_11[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 65,731,763 (250.75 MB)
#  Trainable params: 21,890,363 (83.51 MB)
#  Non-trainable params: 60,672 (237.00 KB)
#  Optimizer params: 43,780,728 (167.01 MB)
